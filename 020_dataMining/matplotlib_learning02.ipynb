# %% [markdown]
# # matplotlib 02

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ### demo 01

# %%
unrate = pd.read_csv("UNRATE.csv")
unrate["DATE"] = pd.to_datetime(unrate["DATE"])
unrate.head(12)
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5
# 5  1948-06-01    3.6
# 6  1948-07-01    3.6
# 7  1948-08-01    3.9
# 8  1948-09-01    3.8
# 9  1948-10-01    3.7
# 10 1948-11-01    3.8
# 11 1948-12-01    4.0

# %%
plt.plot()
plt.show()

# %%
first_twelve = unrate[0:12]
plt.plot(first_twelve["DATE"],first_twelve["VALUE"]) # x, y
plt.xticks(rotation = 45)
plt.xlabel("Month")
plt.show()
# Out:
# /Users/Tommy/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### demo02

# %%
# fig = plt.figure()
fig = plt.figure(figsize=(13,6))
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,4)
ax1.plot(np.random.randint(1,5,5),np.arange(5))
ax2.plot(np.arange(10)*3,np.arange(10))
plt.show()

# %%
unrate["MONTH"] = unrate["DATE"].dt.month  # ?????????
fig = plt.figure
plt.plot(unrate[0:12]["MONTH"],unrate[0:12]["VALUE"],c="red")
plt.plot(unrate[12:24]["MONTH"],unrate[12:24]["VALUE"],c="green")
# plt.legend(loc = "best")

plt.show()

# %% [markdown]
# ### demo03

# %%
fandango =  pd.read_csv("fandango_score_comparison.csv") # movies
num_cols = ["FILM","Metacritic_User","IMDB","Metacritic_norm","Fandango_Stars"]
norm_reviews = fandango[num_cols]
norm_reviews.head(5)
# Out:
#                              FILM  Metacritic_User  IMDB  Metacritic_norm  \
# 0  Avengers: Age of Ultron (2015)              7.1   7.8             3.30
# 1               Cinderella (2015)              7.5   7.1             3.35
# 2                  Ant-Man (2015)              8.1   7.8             3.20
# 3          Do You Believe? (2015)              4.7   5.4             1.10
# 4   Hot Tub Time Machine 2 (2015)              3.4   5.1             1.45
#
#    Fandango_Stars
# 0             5.0
# 1             5.0
# 2             5.0
# 3             5.0
# 4             3.5

# %%
bar_heights= norm_reviews.loc[0,num_cols].values # 尴尬， 不知道为什么list第一个元素 是 字符串
bar_heights[0]= 5
print(bar_heights)
bar_postions = np.arange(5)+0.75
print(bar_postions)
fig = plt.figure()
ax1 = fig.add_subplot()
ax1.bar( bar_postions,bar_heights,0.3)   
plt.show()
# Out:
# [5 7.1 7.8 3.3 5.0]
# [0.75 1.75 2.75 3.75 4.75]

# %%
fig, ax = plt.subplots()
ax.scatter(norm_reviews["Metacritic_User"],norm_reviews["IMDB"], alpha =0.5)
plt.show();

# %% [markdown]
# ### demo 04 seaborn  高级画图

# %%
import seaborn as sns
import matplotlib as mpl
# %matplotlib inline

# %%
def sinPlot(flip = 1):
    x = np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x, np.sin(x + i * 0.5) *(7-i)*flip)

# %%
sns.set()

sinPlot()

# %%
iris = sns.load_dataset("iris") # 鸢尾花数据集
sns.pairplot(iris) #特征与特征关系

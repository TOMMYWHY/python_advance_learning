# %% [markdown]
# ## matplotlib 使用

# %% [markdown]
# ### Demo01

# %% [markdown]
# import matplotlib.pyplot as plt
#
# plt.figure()
# plt.plot([1,0,9],[4,5,6])
# plt.show()

# %% [markdown]
# ### demo02

# %%
plt.figure(figsize=(14,8),dpi=80)
plt.plot([1,2,3,4,5,6,7],[17,15,18,18,15,11,13])
plt.savefig("test.png")
plt.show()

# %% [markdown]
#  ### demo03

# %%
import random

x = range(60)
y_city = [random.uniform(15,18) for i in x]

# %%
y_city
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a3560b522fe1> in <module>
# ----> 1 y_city
#
# NameError: name 'y_city' is not defined
